# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\swaya\OneDrive\Desktop\Python_pandas_projects\Sales-Data-Analysis.xlsx - Raw.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN   Order ID       Date        Product      Price   Quantity
# 1         NaN      10452  11/7/2022          Fries       3.49     573.07
# 2         NaN      10453  11/7/2022      Beverages       2.95     745.76
# 3         NaN      10454  11/7/2022  Sides & Other       4.99     200.40
# 4         NaN      10455  11/8/2022        Burgers      12.99     569.67
#
#       Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0  Purchase Type  Payment Method             Manager       City
# 1        Online        Gift Card    Tom      Jackson     London
# 2        Online        Gift Card         Pablo Perez     Madrid
# 3      In-store        Gift Card       Joao    Silva     Lisbon
# 4      In-store      Credit Card       Walter Muller     Berlin

# %%
data.shape
# Out:
# (255, 10)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='str')

# %%
data.drop(columns='Unnamed: 0',inplace=True)

# %%
data.head(2)
# Out:
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5     Unnamed: 6  \
# 0   Order ID       Date    Product      Price   Quantity  Purchase Type
# 1      10452  11/7/2022      Fries       3.49     573.07        Online
#
#        Unnamed: 7        Unnamed: 8 Unnamed: 9
# 0  Payment Method           Manager       City
# 1       Gift Card  Tom      Jackson     London

# %%
data.loc[0]
# Out:
# Unnamed: 1          Order ID
# Unnamed: 2              Date
# Unnamed: 3           Product
# Unnamed: 4             Price
# Unnamed: 5          Quantity
# Unnamed: 6     Purchase Type
# Unnamed: 7    Payment Method
# Unnamed: 8           Manager
# Unnamed: 9              City
# Name: 0, dtype: str

# %%
data.columns=data.loc[0]

# %%
data.head()
# Out:
# 0  Order ID       Date        Product  Price  Quantity  Purchase Type  \
# 0  Order ID       Date        Product  Price  Quantity  Purchase Type
# 1     10452  11/7/2022          Fries   3.49    573.07        Online
# 2     10453  11/7/2022      Beverages   2.95    745.76        Online
# 3     10454  11/7/2022  Sides & Other   4.99    200.40      In-store
# 4     10455  11/8/2022        Burgers  12.99    569.67      In-store
#
# 0  Payment Method             Manager    City
# 0  Payment Method             Manager    City
# 1       Gift Card    Tom      Jackson  London
# 2       Gift Card         Pablo Perez  Madrid
# 3       Gift Card       Joao    Silva  Lisbon
# 4     Credit Card       Walter Muller  Berlin

# %%
data.drop(0,inplace=True)

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price Quantity Purchase Type  \
# 1    10452  11/7/2022               Fries   3.49   573.07       Online
# 2    10453  11/7/2022           Beverages   2.95   745.76       Online
# 3    10454  11/7/2022       Sides & Other   4.99   200.40     In-store
# 4    10455  11/8/2022             Burgers  12.99   569.67     In-store
# 5    10456  11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
#
# 0 Payment Method             Manager    City
# 1      Gift Card    Tom      Jackson  London
# 2      Gift Card         Pablo Perez  Madrid
# 3      Gift Card       Joao    Silva  Lisbon
# 4    Credit Card       Walter Muller  Berlin
# 5    Credit Card       Walter Muller  Berlin

# %%
data.Manager
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# 254         Walter Muller
# Name: Manager, Length: 254, dtype: str

# %%
data.Manager.unique()
# Out:
# <StringArray>
# [  'Tom      Jackson', '       Pablo Perez',      'Joao    Silva',
#       'Walter Muller',      'Remy    Monet',         'Remy Monet',
#   '       Remy Monet',     'Remy     Monet',        'Pablo Perez',
#       'Pablo   Perez',       'Pablo  Perez',     'Pablo    Perez',
#          'Joao Silva',        'Tom Jackson']
# Length: 14, dtype: str

# %%
data['Manager']=data['Manager'].str.strip().str.replace(r'\s+',' ',regex=True)

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price Quantity Purchase Type  \
# 1    10452  11/7/2022               Fries   3.49   573.07       Online
# 2    10453  11/7/2022           Beverages   2.95   745.76       Online
# 3    10454  11/7/2022       Sides & Other   4.99   200.40     In-store
# 4    10455  11/8/2022             Burgers  12.99   569.67     In-store
# 5    10456  11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data.Manager.nunique()
# Out:
# 5

# %%
data.describe()
# Out:
# 0      Order ID       Date  Product  Price Quantity Purchase Type  \
# count       254        254      254    254      254           254
# unique      254         53        5      7       29             3
# top       10452  11/9/2022  Burgers  12.99   200.40       Online
# freq          1          5       52     52       49           107
#
# 0      Payment Method      Manager    City
# count             254          254     254
# unique              3            5       5
# top       Credit Card  Tom Jackson  London
# freq              120           75      75

# %%
data.isnull().sum()
# Out:
# 0
# Order ID          0
# Date              0
# Product           0
# Price             0
# Quantity          0
# Purchase Type     0
# Payment Method    0
# Manager           0
# City              0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.dtypes
# Out:
# 0
# Order ID          str
# Date              str
# Product           str
# Price             str
# Quantity          str
# Purchase Type     str
# Payment Method    str
# Manager           str
# City              str
# dtype: object

# %%
data.Quantity=data.Quantity.astype(float)

# %%
data.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Price', 'Quantity', 'Purchase Type',
#        'Payment Method', 'Manager', 'City'],
#       dtype='str', name=0)

# %%
data.dtypes
# Out:
# 0
# Order ID              str
# Date                  str
# Product               str
# Price                 str
# Quantity          float64
# Purchase Type         str
# Payment Method        str
# Manager               str
# City                  str
# dtype: object

# %%
data.Quantity=data.Quantity.astype(int)

# %%
data.Quantity
# Out:
# 1      573
# 2      745
# 3      200
# 4      569
# 5      201
#       ...
# 250    200
# 251    754
# 252    281
# 253    630
# 254    677
# Name: Quantity, Length: 254, dtype: int64

# %%
data['Order ID']=data['Order ID'].astype(int)

# %%
data['Order ID']
# Out:
# 1      10452
# 2      10453
# 3      10454
# 4      10455
# 5      10456
#        ...
# 250    10709
# 251    10710
# 252    10711
# 253    10712
# 254    10713
# Name: Order ID, Length: 254, dtype: int64

# %%
data.Date=pd.to_datetime(data.Date)

# %%
data['Date']
# Out:
# 1     2022-11-07
# 2     2022-11-07
# 3     2022-11-07
# 4     2022-11-08
# 5     2022-11-08
#          ...
# 250   2022-12-28
# 251   2022-12-29
# 252   2022-12-29
# 253   2022-12-29
# 254   2022-12-29
# Name: Date, Length: 254, dtype: datetime64[us]
